# %%
import pandas as pd

# %%
oo= pd.read_csv('C:\\Users\\User pc\\Downloads\\Ex_Files_Pandas_EssT\\ExerciseFiles\\data\\olympics.csv')

## data frame name is oo

# %%
oo

## Table not showing well because there is are irrelvant rows so we need to specify the rows it should start  from
# Out:
#       List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                    NaN
# 1      DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                    NaN
# 3                                                   City
# 4                                                 Athens
# ...                                                  ...
# 29215                                            Beijing
# 29216                                            Beijing
# 29217                                            Beijing
# 29218                                            Beijing
# 29219                                            Beijing
#
#       Unnamed: 1 Unnamed: 2       Unnamed: 3            Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN              NaN                   NaN        NaN
# ...

# %%
oo = pd.read_csv('C:\\Users\\User pc\\Downloads\\Ex_Files_Pandas_EssT\\ExerciseFiles\\data\\olympics.csv', skiprows=4)

# %%
oo
### adding the skip rows have made us jump some rows that irelevant.

## OLYMPICS TABLE
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
oo['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo.NOC


## LIST OF NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(oo['NOC'])
# Out:
# pandas.core.series.Series

# %%
oo[['Edition', 'Athlete', 'Medal']]

## LIST OF EDITION , ATHLETE AND MEDALS WON
# Out:
#        Edition               Athlete   Medal
# 0         1896         HAJOS, Alfred    Gold
# 1         1896      HERSCHMANN, Otto  Silver
# 2         1896     DRIVAS, Dimitrios  Bronze
# 3         1896    MALOKINIS, Ioannis    Gold
# 4         1896    CHASAPIS, Spiridon  Silver
# ...        ...                   ...     ...
# 29211     2008        ENGLICH, Mirko  Silver
# 29212     2008  MIZGAITIS, Mindaugas  Bronze
# 29213     2008       PATRIKEEV, Yuri  Bronze
# 29214     2008         LOPEZ, Mijain    Gold
# 29215     2008        BAROEV, Khasan  Silver
#
# [29216 rows x 3 columns]

# %%
type(oo[['Edition', 'Athlete', 'Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
oo.shape

## the 29216 is the number of rows and the 10 is columns
# Out:
# (29216, 10)

# %%
oo.shape[1]

## to see number of columns
# Out:
# 10

# %%
oo.head(7)

### FIRST SEVEN ON THE TABLE
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver
# 5             1200m freestyle            M  Bronze
# ...

# %%
oo.tail(7)

### LAST SEVEN ROWS
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R         WHEELER, Adam
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R    KHUSHTOV, Aslanbek
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29209  USA    Men   84 - 96kg            M  Bronze
# 29210  RUS    Men   84 - 96kg            M    Gold
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# ...

# %%
oo.info()
## provide information about data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
### VALUE COUNT

###value_counts() function returns object containing counts of unique values. The resulting object will be in descending order so that the first element is the most frequently-occurring element


oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.City.value_counts()

### LIST OF MATCHES PER CITY
# Out:
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# London                   1618
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Stockholm                 885
# Melbourne / Stockholm     885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: City, dtype: int64

# %%
oo.Gender.value_counts(ascending=True, dropna=False)

### TOTAL NUMBER OF MEN AND WOMEN DURING ALL THE MATCHES
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
### SORT is use to sort values n a series

oo.Athlete.sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
## sorting using more than one characteristics

oo.sort_values(by = ['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
oo.sort_values(by = ['Edition', 'Athlete']).tail(20)
# Out:
#           City  Edition       Sport       Discipline  \
# 27701  Beijing     2008   Athletics        Athletics
# 27176  Beijing     2008    Aquatics           Diving
# 29075  Beijing     2008  Volleyball       Volleyball
# 28585  Beijing     2008      Hockey           Hockey
# 27341  Beijing     2008    Aquatics         Swimming
# 28191  Beijing     2008     Fencing          Fencing
# 28989  Beijing     2008   Taekwondo        Taekwondo
# 27394  Beijing     2008    Aquatics         Swimming
# 28857  Beijing     2008    Shooting         Shooting
# 28396  Beijing     2008  Gymnastics      Rhythmic G.
# 29172  Beijing     2008   Wrestling  Wrestling Free.
# 28308  Beijing     2008  Gymnastics      Artistic G.
# 28314  Beijing     2008  Gymnastics      Artistic G.
# 28342  Beijing     2008  Gymnastics      Artistic G.
# 27900  Beijing     2008      Boxing           Boxing
# 28095  Beijing     2008  Equestrian         Dressage
# 28819  Beijing     2008     Sailing          Sailing
# ...

# %%
### BOOLEAN 
# == use to compare factor
# AND  &
# OR |
# NOT -

# %%
oo.Medal == 'Gold'

## comparing each row using a boolean
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
oo[oo.Medal == 'Gold']
## Only list of ppl who has wn gold
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
### Selecting using two factors

oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
oo[(oo.City == 'Paris') & (oo.Sport == 'Wrestling') & (oo.Gender == 'Men')]
# Out:
#        City  Edition      Sport       Discipline                     Athlete  \
# 4965  Paris     1924  Wrestling  Wrestling Free.                HINES, Bryan
# 4966  Paris     1924  Wrestling  Wrestling Free.         PIHLAJAMÄKI, Kustaa
# 4967  Paris     1924  Wrestling  Wrestling Free.          MÄKINEN, Kaarlo E.
# 4968  Paris     1924  Wrestling  Wrestling Free.          MAC DONALD, Andrew
# 4969  Paris     1924  Wrestling  Wrestling Free.               STEELE, Harry
# 4970  Paris     1924  Wrestling  Wrestling Free.               WERNLI, Henri
# 4971  Paris     1924  Wrestling  Wrestling Free.           NAITO, Katsutoshi
# 4972  Paris     1924  Wrestling  Wrestling Free.                 REED, Robin
# 4973  Paris     1924  Wrestling  Wrestling Free.             NEWTON, Chester
# 4974  Paris     1924  Wrestling  Wrestling Free.              HAAVISTO, Arvo
# 4975  Paris     1924  Wrestling  Wrestling Free.                VIS, Russell
# ...

# %%
### string  handling
##it is use to search for string

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
oo[oo.Athlete == 'OWENS, Jesse']
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
oo[oo.Athlete.str.contains ('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
oo.City.value_counts()
# Out:
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# London                   1618
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Stockholm                 885
# Melbourne / Stockholm     885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: City, dtype: int64

# %%
x= oo[(oo.Medal == 'Gold') & (oo.Discipline == 'Badminton') & (oo.Gender == 'Men')] 

x.sort_values(by = 'Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
x
x.City.value_counts()
# Out:
# Atlanta      8
# Sydney       8
# Athens       8
# Beijing      8
# Barcelona    6
# Name: City, dtype: int64

# %%
 oo[(oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Event == '100m') | (oo.Event == 'Sprint')]
# Out:
#                         City  Edition      Sport Discipline  \
# 13                    Athens     1896  Athletics  Athletics
# 231                    Paris     1900  Athletics  Athletics
# 737                 St Louis     1904  Athletics  Athletics
# 1191                  London     1908  Athletics  Athletics
# 2022               Stockholm     1912  Athletics  Athletics
# 2996                 Antwerp     1920  Athletics  Athletics
# 4236                   Paris     1924  Athletics  Athletics
# 5095               Amsterdam     1928  Athletics  Athletics
# 5806             Los Angeles     1932  Athletics  Athletics
# 6427                  Berlin     1936  Athletics  Athletics
# 7302                  London     1948  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# ...

# %%
# Out:
#             City  Edition      Sport Discipline            Athlete  NOC  \
# 19859  Barcelona     1992  Athletics  Athletics  CHRISTIE, Linford  GBR
# 21598    Atlanta     1996  Athletics  Athletics    BAILEY, Donovan  CAN
# 23521     Sydney     2000  Athletics  Athletics    GREENE, Maurice  USA
# 25539     Athens     2004  Athletics  Athletics     GATLIN, Justin  USA
# 27552    Beijing     2008  Athletics  Athletics        BOLT, Usain  JAM
#
#       Gender Event Event_gender Medal
# 19859    Men  100m            M  Gold
# 21598    Men  100m            M  Gold
# 23521    Men  100m            M  Gold
# 25539    Men  100m            M  Gold
# 27552    Men  100m            M  Gold

# %%
rec= oo[oo.Edition >= 1984]

# %%
rec.NOC.value_counts()
# Out:
# USA    1837
# AUS     762
# GER     691
# CHN     679
# RUS     638
#        ...
# ISV       1
# AHO       1
# DJI       1
# SEN       1
# AFG       1
# Name: NOC, Length: 124, dtype: int64

# %%
import pandas as pd
oo = pd.read_csv('C:\\Users\\User pc\\Downloads\\Ex_Files_Pandas_EssT\\ExerciseFiles\\data\\olympics.csv', skiprows=4)

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

## this is what we make us view the plots

# %%
### what where the different sports in the first olympic? plot them using different graphs

fo= oo[oo.Edition == 1896]
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts(). plot(kind = 'line', figsize=(10,3));

# %%
## BAR CHART 

fo.Sport.value_counts().plot(kind = 'bar');
# Out:
# <AxesSubplot:>

# %%
## Horizontal plot  

fo.Sport.value_counts().plot(kind = 'barh', color = 'yellow');

# %%
## PIE CHART 

fo.Sport.value_counts().plot(kind = 'pie', colormap = 'summer');

# %%
## SEABORN

import seaborn as sms
sms.countplot(x= 'Medal', data = oo, hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
### Plot the number of medals achieved by the chinese team (men and women ) in Bejing 2008  using matplotlib and seaborn

be = oo[(oo.City == 'Beijing') & (oo.NOC == 'CHN') & (oo.Edition == 2008)]

ge= be[['Edition', 'City', 'Gender', 'Medal']]

# %%
ge
# Out:
#        Edition     City Gender   Medal
# 27176     2008  Beijing    Men  Silver
# 27177     2008  Beijing  Women  Bronze
# 27178     2008  Beijing  Women    Gold
# 27180     2008  Beijing    Men  Bronze
# 27181     2008  Beijing    Men    Gold
# ...        ...      ...    ...     ...
# 29138     2008  Beijing    Men  Silver
# 29140     2008  Beijing    Men    Gold
# 29156     2008  Beijing  Women  Silver
# 29171     2008  Beijing  Women    Gold
# 29204     2008  Beijing    Men  Silver
#
# [184 rows x 4 columns]

# %%
ge.Gender.value_counts()
# Out:
# Women    128
# Men       56
# Name: Gender, dtype: int64

# %%
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
ge.Gender.value_counts().plot(kind = 'bar', color = 'Green');

# %%
## Using seaborn.


import seaborn as sms
sms.countplot(x= 'Gender', data = ge)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
## Using seaborn.


import seaborn as sms
sms.countplot(x= 'Medal', data = ge, hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
##Plot the number of gold, silver, and bronze medals for each gender

ge.Medal.value_counts().plot(kind = 'bar', color = 'black');

# %%
### INDEXING 


import pandas as pd
 
oo = pd.read_csv('C:\\Users\\User pc\\Downloads\\Ex_Files_Pandas_EssT\\ExerciseFiles\\data\\olympics.csv', skiprows=4)

# %%
oo
# Out:
#        index     City  Edition      Sport       Discipline  \
# 0          0   Athens     1896   Aquatics         Swimming
# 1          1   Athens     1896   Aquatics         Swimming
# 2          2   Athens     1896   Aquatics         Swimming
# 3          3   Athens     1896   Aquatics         Swimming
# 4          4   Athens     1896   Aquatics         Swimming
# ...      ...      ...      ...        ...              ...
# 29211  29211  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  29212  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213  29213  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214  29214  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215  29215  Beijing     2008  Wrestling  Wrestling Gre-R
#
#                     Athlete  NOC Gender                       Event  \
# 0             HAJOS, Alfred  HUN    Men              100m freestyle
# 1          HERSCHMANN, Otto  AUT    Men              100m freestyle
# ...

# %%
### check type of the index 

type (oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
### HOW TO CHANGE A SERIES TO INDEX. EG CHANGING THE ATHLETE TO INDEX adding the inplace = true helps the changes to be permanent
oo.set_index('Athlete',inplace= True)
oo.head()
# Out:
#                     level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HAJOS, Alfred             0      0  Athens     1896  Aquatics   Swimming  HUN
# HERSCHMANN, Otto          1      1  Athens     1896  Aquatics   Swimming  AUT
# DRIVAS, Dimitrios         2      2  Athens     1896  Aquatics   Swimming  GRE
# MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming  GRE
# CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming  GRE
#
#                    Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred         Men              100m freestyle            M    Gold
# HERSCHMANN, Otto      Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios     Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis    Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon    Men  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=True)
ath= oo.set_index('Athlete')
ath.head()
# Out:
#                     level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HAJOS, Alfred             0      0  Athens     1896  Aquatics   Swimming  HUN
# HERSCHMANN, Otto          1      1  Athens     1896  Aquatics   Swimming  AUT
# DRIVAS, Dimitrios         2      2  Athens     1896  Aquatics   Swimming  GRE
# MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming  GRE
# CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming  GRE
#
#                    Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred         Men              100m freestyle            M    Gold
# HERSCHMANN, Otto      Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios     Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis    Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon    Men  100m freestyle for sailors            M  Silver

# %%
ath.reset_index(inplace=True)

# %%
ath.head()
# Out:
#               Athlete  level_0  index    City  Edition     Sport Discipline  \
# 0       HAJOS, Alfred        0      0  Athens     1896  Aquatics   Swimming
# 1    HERSCHMANN, Otto        1      1  Athens     1896  Aquatics   Swimming
# 2   DRIVAS, Dimitrios        2      2  Athens     1896  Aquatics   Swimming
# 3  MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming
# 4  CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
### SORT INDEX

ath.set_index('Athlete', inplace = True)

# %%
ath.head()
# Out:
#                     level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HAJOS, Alfred             0      0  Athens     1896  Aquatics   Swimming  HUN
# HERSCHMANN, Otto          1      1  Athens     1896  Aquatics   Swimming  AUT
# DRIVAS, Dimitrios         2      2  Athens     1896  Aquatics   Swimming  GRE
# MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming  GRE
# CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming  GRE
#
#                    Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred         Men              100m freestyle            M    Gold
# HERSCHMANN, Otto      Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios     Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis    Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon    Men  100m freestyle for sailors            M  Silver

# %%
##After seting the index to athlete name, you can now sort the index. 

ath.sort_index(inplace= True)
ath.head()
# Out:
#                           level_0  index     City  Edition       Sport  \
# Athlete
# AABYE, Edgar                  651    651    Paris     1900  Tug of War
# AALTONEN, Arvo Ossian        2849   2849  Antwerp     1920    Aquatics
# AALTONEN, Arvo Ossian        2852   2852  Antwerp     1920    Aquatics
# AALTONEN, Paavo Johannes     7716   7716   London     1948  Gymnastics
# AALTONEN, Paavo Johannes     7730   7730   London     1948  Gymnastics
#
#                            Discipline  NOC Gender              Event  \
# Athlete
# AABYE, Edgar               Tug of War  ZZX    Men         tug of war
# AALTONEN, Arvo Ossian        Swimming  FIN    Men  200m breaststroke
# AALTONEN, Arvo Ossian        Swimming  FIN    Men  400m breaststroke
# AALTONEN, Paavo Johannes  Artistic G.  FIN    Men       pommel horse
# AALTONEN, Paavo Johannes  Artistic G.  FIN    Men   team competition
#
#                          Event_gender   Medal
# Athlete
# AABYE, Edgar                        M    Gold
# ...

# %%
### to sort the inex in a descending oreder 

ath.sort_index(inplace=True, ascending= False)

# %%
ath.head()
# Out:
#                    level_0  index      City  Edition     Sport Discipline  \
# Athlete
# ÖSTRAND, Per-Olof     8051   8051  Helsinki     1952  Aquatics   Swimming
# ÖSTMO, Ole             596    596     Paris     1900  Shooting   Shooting
# ÖSTMO, Ole             621    621     Paris     1900  Shooting   Shooting
# ÖSTMO, Ole             608    608     Paris     1900  Shooting   Shooting
# ÖSTMO, Ole             603    603     Paris     1900  Shooting   Shooting
#
#                    NOC Gender                          Event Event_gender  \
# Athlete
# ÖSTRAND, Per-Olof  SWE    Men                 400m freestyle            M
# ÖSTMO, Ole         NOR    Men  army rifle, 300m, 3 positions            M
# ÖSTMO, Ole         NOR    Men               free rifle, team            M
# ÖSTMO, Ole         NOR    Men     army rifle, 300m, standing            M
# ÖSTMO, Ole         NOR    Men        army rifle, 300m, prone            M
#
#                     Medal
# Athlete
# ...

# %%
ath.index

ath.loc['BOLT, Usain']
# Out:
#              level_0  index     City  Edition      Sport Discipline  NOC  \
# Athlete
# BOLT, Usain    27552  27552  Beijing     2008  Athletics  Athletics  JAM
# BOLT, Usain    27603  27603  Beijing     2008  Athletics  Athletics  JAM
# BOLT, Usain    27570  27570  Beijing     2008  Athletics  Athletics  JAM
#
#             Gender         Event Event_gender Medal
# Athlete
# BOLT, Usain    Men          100m            M  Gold
# BOLT, Usain    Men  4x100m relay            M  Gold
# BOLT, Usain    Men          200m            M  Gold

# %%
oo.head()
# Out:
#               Athlete  level_0  index    City  Edition     Sport Discipline  \
# 0       HAJOS, Alfred        0      0  Athens     1896  Aquatics   Swimming
# 1    HERSCHMANN, Otto        1      1  Athens     1896  Aquatics   Swimming
# 2   DRIVAS, Dimitrios        2      2  Athens     1896  Aquatics   Swimming
# 3  MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming
# 4  CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
####ILOC is use to find a particular row using an integer 

oo.iloc[127]
# Out:
# Athlete         KARASEVDAS, Pantelis
# level_0                          127
# index                            127
# City                          Athens
# Edition                         1896
# Sport                       Shooting
# Discipline                  Shooting
# NOC                              GRE
# Gender                           Men
# Event               army rifle, 200m
# Event_gender                       M
# Medal                           Gold
# Name: 127, dtype: object

# %%
oo.iloc[[127, 560, 700, 800]]
# Out:
#                   Athlete  level_0  index      City  Edition      Sport  \
# 127  KARASEVDAS, Pantelis      127    127    Athens     1896   Shooting
# 560        BILLARD, Emile      560    560     Paris     1900    Sailing
# 700      DANIELS, Charles      700    700  St Louis     1904   Aquatics
# 800        NEWTON, Arthur      800    800  St Louis     1904  Athletics
#
#     Discipline  NOC Gender                   Event Event_gender   Medal
# 127   Shooting  GRE    Men        army rifle, 200m            M    Gold
# 560    Sailing  FRA    Men                  10-20t            X    Gold
# 700   Swimming  USA    Men  50y freestyle (45.72m)            M  Bronze
# 800  Athletics  USA    Men                marathon            M  Bronze

# %%
oo.iloc[1:4]
# Out:
#               Athlete  level_0  index    City  Edition     Sport Discipline  \
# 1    HERSCHMANN, Otto        1      1  Athens     1896  Aquatics   Swimming
# 2   DRIVAS, Dimitrios        2      2  Athens     1896  Aquatics   Swimming
# 3  MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold

# %%
oo.head()
# Out:
#               Athlete  level_0  index    City  Edition     Sport Discipline  \
# 0       HAJOS, Alfred        0      0  Athens     1896  Aquatics   Swimming
# 1    HERSCHMANN, Otto        1      1  Athens     1896  Aquatics   Swimming
# 2   DRIVAS, Dimitrios        2      2  Athens     1896  Aquatics   Swimming
# 3  MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming
# 4  CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
oo[['Edition', 'Event', 'Medal']]
# Out:
#        Edition                       Event   Medal
# 0         1896              100m freestyle    Gold
# 1         1896              100m freestyle  Silver
# 2         1896  100m freestyle for sailors  Bronze
# 3         1896  100m freestyle for sailors    Gold
# 4         1896  100m freestyle for sailors  Silver
# ...        ...                         ...     ...
# 29211     2008                   84 - 96kg  Silver
# 29212     2008                  96 - 120kg  Bronze
# 29213     2008                  96 - 120kg  Bronze
# 29214     2008                  96 - 120kg    Gold
# 29215     2008                  96 - 120kg  Silver
#
# [29216 rows x 3 columns]

# %%
oo.Edition.value_counts().sort_index()
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().sort_index(). plot( kind = 'line', figsize=(20,8));

# %%
lo= oo[oo.Edition == 2008]

# %%
lo
# Out:
#                     Athlete  level_0  index     City  Edition      Sport  \
# 27174        GALPERIN, Gleb    27174  27174  Beijing     2008   Aquatics
# 27175      MITCHAM, Matthew    27175  27175  Beijing     2008   Aquatics
# 27176           ZHOU, Luxin    27176  27176  Beijing     2008   Aquatics
# 27177             WANG, Xin    27177  27177  Beijing     2008   Aquatics
# 27178          CHEN, Ruolin    27178  27178  Beijing     2008   Aquatics
# ...                     ...      ...    ...      ...      ...        ...
# 29211        ENGLICH, Mirko    29211  29211  Beijing     2008  Wrestling
# 29212  MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# 29213       PATRIKEEV, Yuri    29213  29213  Beijing     2008  Wrestling
# 29214         LOPEZ, Mijain    29214  29214  Beijing     2008  Wrestling
# 29215        BAROEV, Khasan    29215  29215  Beijing     2008  Wrestling
#
#             Discipline  NOC Gender         Event Event_gender   Medal
# ...

# %%
noc = pd.read_csv('C:\\Users\\User pc\\Downloads\\Ex_Files_Pandas_EssT\\ExerciseFiles\\data\\Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')

# %%
noc
# Out:
#              Country Int Olympic Committee code ISO code        Country.1
# 0        Afghanistan                        AFG       AF      Afghanistan
# 1            Albania                        ALB       AL          Albania
# 2            Algeria                        ALG       DZ          Algeria
# 3    American Samoa*                        ASA       AS  American Samoa*
# 4            Andorra                        AND       AD          Andorra
# ..               ...                        ...      ...              ...
# 196          Vietnam                        VIE       VN          Vietnam
# 197  Virgin Islands*                        ISV       VI  Virgin Islands*
# 198            Yemen                        YEM       YE            Yemen
# 199           Zambia                        ZAM       ZM           Zambia
# 200         Zimbabwe                        ZIM       ZW         Zimbabwe
#
# [201 rows x 4 columns]

# %%
#how to compare if twoo column are same 

from the result both table are same
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
#### change noc index to 'Int Olympic Committee code'

noc.set_index('Int Olympic Committee code', inplace=True)

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008 = lo.NOC.value_counts()

# %%
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# SUD      1
# EGY      1
# MDA      1
# TOG      1
# MRI      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008']= medal_2008

## combining the two tables

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
##list of countries that didnt medal

noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...

# %%
####GROUB BY 


oo.groupby('Edition')

# %%
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#                         Athlete  level_0  index    City  Edition          Sport  \
#   0               HAJOS, Alfred        0      0  Athens     1896       Aquatics
#   1            HERSCHMANN, Otto        1      1  Athens     1896       Aquatics
#   2           DRIVAS, Dimitrios        2      2  Athens     1896       Aquatics
#   3          MALOKINIS, Ioannis        3      3  Athens     1896       Aquatics
#   4          CHASAPIS, Spiridon        4      4  Athens     1896       Aquatics
#   ..                        ...      ...    ...     ...      ...            ...
#   146             JENSEN, Viggo      146    146  Athens     1896  Weightlifting
#   147       ELLIOTT, Launceston      147    147  Athens     1896  Weightlifting
#   148  CHRISTOPOULOS, Stephanos      148    148  Athens     1896      Wrestling
#   149            SCHUMANN, Carl      149    149  Athens     1896      Wrestling
#   150          TSITAS, Georgios      150    150  Athens     1896      Wrestling
#
# ...

# %%
### iterate groups

for group_key, group_value in oo.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#                       Athlete  level_0  index    City  Edition          Sport  \
# 0               HAJOS, Alfred        0      0  Athens     1896       Aquatics
# 1            HERSCHMANN, Otto        1      1  Athens     1896       Aquatics
# 2           DRIVAS, Dimitrios        2      2  Athens     1896       Aquatics
# 3          MALOKINIS, Ioannis        3      3  Athens     1896       Aquatics
# 4          CHASAPIS, Spiridon        4      4  Athens     1896       Aquatics
# ..                        ...      ...    ...     ...      ...            ...
# 146             JENSEN, Viggo      146    146  Athens     1896  Weightlifting
# 147       ELLIOTT, Launceston      147    147  Athens     1896  Weightlifting
# 148  CHRISTOPOULOS, Stephanos      148    148  Athens     1896      Wrestling
# 149            SCHUMANN, Carl      149    149  Athens     1896      Wrestling
# 150          TSITAS, Georgios      150    150  Athens     1896      Wrestling
#
# ...

# %%
#### GROUPBY COMPUTATION


### 1.Groupby using size

oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
### aggregate function helps to perform multiple statitics

oo.groupby(['Edition', 'NOC', 'Medal']).agg('count')
# Out:
#                     Athlete  level_0  index  City  Sport  Discipline  Gender  \
# Edition NOC Medal
# 1896    AUS Gold          2        2      2     2      2           2       2
#         AUT Bronze        2        2      2     2      2           2       2
#             Gold          2        2      2     2      2           2       2
#             Silver        1        1      1     1      1           1       1
#         DEN Bronze        3        3      3     3      3           3       3
# ...                     ...      ...    ...   ...    ...         ...     ...
# 2008    UZB Silver        2        2      2     2      2           2       2
#         VEN Bronze        1        1      1     1      1           1       1
#         VIE Silver        1        1      1     1      1           1       1
#         ZIM Gold          1        1      1     1      1           1       1
#             Silver        3        3      3     3      3           3       3
#
# ...

# %%
###total number of medals awarded at the history of the occasion.

oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
oo.groupby('Edition').size().plot(kind = 'line')
# Out:
# <AxesSubplot:xlabel='Edition'>

# %%
oo.groupby('NOC').agg({'Edition': ['count', 'min', 'max']})

##the dicts function uses {} this is when a particular column is selected. The aggregate is use to get numerous statiscal data.
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
##Unstack and stack

##ATHLETE THAT WON MEDALS FROM BENJING IN 100M AND 200M


mw = oo[(oo.Edition ==2008) & ((oo.Event == '100m') | (oo.Event == '200m'))]

# %%
mw
# Out:
#                         Athlete  level_0  index     City  Edition      Sport  \
# 27551               DIX, Walter    27551  27551  Beijing     2008  Athletics
# 27552               BOLT, Usain    27552  27552  Beijing     2008  Athletics
# 27553         THOMPSON, Richard    27553  27553  Beijing     2008  Athletics
# 27554        FRASER, Shelly-ann    27554  27554  Beijing     2008  Athletics
# 27555          SIMPSON, Sherone    27555  27555  Beijing     2008  Athletics
# 27556           STEWART, Kerron    27556  27556  Beijing     2008  Athletics
# 27569               DIX, Walter    27569  27569  Beijing     2008  Athletics
# 27570               BOLT, Usain    27570  27570  Beijing     2008  Athletics
# 27571           CRAWFORD, Shawn    27571  27571  Beijing     2008  Athletics
# 27572           STEWART, Kerron    27572  27572  Beijing     2008  Athletics
# 27573  CAMPBELL-BROWN, Veronica    27573  27573  Beijing     2008  Athletics
# ...

# %%
g= mw.groupby(['NOC', 'Gender', 'Discipline', 'Event']).size()

# %%
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df= g.unstack(['Discipline', 'Event'])
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
###### STACK FUNCTION

##When it returns value , it won't bring any null or empty function. Stacking give  taller frame.


df.stack()
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
df.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
###  UNSTACK
##We return a series of dataframe, you can fill the nan value to be zero.

df.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
df.unstack('Gender')
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
x= oo[(oo.NOC == 'USA') & (oo.Medal == 'Gold')]

# %%
x
# Out:
#                 Athlete  level_0  index     City  Edition       Sport  \
# 13        BURKE, Thomas       13     13   Athens     1896   Athletics
# 15       CURTIS, Thomas       15     15   Athens     1896   Athletics
# 21        BURKE, Thomas       21     21   Athens     1896   Athletics
# 27      GARRETT, Robert       27     27   Athens     1896   Athletics
# 29        CLARK, Ellery       29     29   Athens     1896   Athletics
# ...                 ...      ...    ...      ...      ...         ...
# 29048      ROONEY, Sean    29048  29048  Beijing     2008  Volleyball
# 29049     SALMON, Riley    29049  29049  Beijing     2008  Volleyball
# 29050  STANLEY, Clayton    29050  29050  Beijing     2008  Volleyball
# 29051  TOUZINSKY, Scott    29051  29051  Beijing     2008  Volleyball
# 29151     CEJUDO, Henry    29151  29151  Beijing     2008   Wrestling
#
#             Discipline  NOC Gender         Event Event_gender Medal
# ...

# %%
x.groupby(['Gender','Medal']).count()
# Out:
#               Athlete  level_0  index  City  Edition  Sport  Discipline   NOC  \
# Gender Medal
# Men    Gold      1520     1520   1520  1520     1520   1520        1520  1520
# Women  Gold       568      568    568   568      568    568         568   568
#
#               Event  Event_gender
# Gender Medal
# Men    Gold    1520          1520
# Women  Gold     568           568

# %%
x.groupby('Gender').agg({'Medal': 'count'}).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
x= oo[(oo.NOC == 'USA') & (oo.Medal == 'Gold')]
x
# Out:
#                 Athlete  level_0  index     City  Edition       Sport  \
# 13        BURKE, Thomas       13     13   Athens     1896   Athletics
# 15       CURTIS, Thomas       15     15   Athens     1896   Athletics
# 21        BURKE, Thomas       21     21   Athens     1896   Athletics
# 27      GARRETT, Robert       27     27   Athens     1896   Athletics
# 29        CLARK, Ellery       29     29   Athens     1896   Athletics
# ...                 ...      ...    ...      ...      ...         ...
# 29048      ROONEY, Sean    29048  29048  Beijing     2008  Volleyball
# 29049     SALMON, Riley    29049  29049  Beijing     2008  Volleyball
# 29050  STANLEY, Clayton    29050  29050  Beijing     2008  Volleyball
# 29051  TOUZINSKY, Scott    29051  29051  Beijing     2008  Volleyball
# 29151     CEJUDO, Henry    29151  29151  Beijing     2008   Wrestling
#
#             Discipline  NOC Gender         Event Event_gender Medal
# ...

# %%
y=x.groupby('Athlete').count()

# %%
y
# Out:
#                        level_0  index  City  Edition  Sport  Discipline  NOC  \
# Athlete
# ABBOTT, Margaret Ives        1      1     1        1      1           1    1
# ABDUR-RAHIM, Shareef         1      1     1        1      1           1    1
# ABELL, Louis                 2      2     2        2      2           2    2
# ABERNATHY, Brent             1      1     1        1      1           1    1
# ABLOWICH, Edgar Allen        1      1     1        1      1           1    1
# ...                        ...    ...   ...      ...    ...         ...  ...
# YOUNG, Kevin Curtis          1      1     1        1      1           1    1
# YOUNG, Tim                   1      1     1        1      1           1    1
# ZAGUNIS, Mariel              2      2     2        2      2           2    2
# ZIMONYI, Robert              1      1     1        1      1           1    1
# ZORN, Zachary                1      1     1        1      1           1    1
#
# ...

# %%
y.Medal.sort_values(ascending=False).head(5). plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
oo
# Out:
#                     Athlete  level_0  index     City  Edition      Sport  \
# 0             HAJOS, Alfred        0      0   Athens     1896   Aquatics
# 1          HERSCHMANN, Otto        1      1   Athens     1896   Aquatics
# 2         DRIVAS, Dimitrios        2      2   Athens     1896   Aquatics
# 3        MALOKINIS, Ioannis        3      3   Athens     1896   Aquatics
# 4        CHASAPIS, Spiridon        4      4   Athens     1896   Aquatics
# ...                     ...      ...    ...      ...      ...        ...
# 29211        ENGLICH, Mirko    29211  29211  Beijing     2008  Wrestling
# 29212  MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# 29213       PATRIKEEV, Yuri    29213  29213  Beijing     2008  Wrestling
# 29214         LOPEZ, Mijain    29214  29214  Beijing     2008  Wrestling
# 29215        BAROEV, Khasan    29215  29215  Beijing     2008  Wrestling
#
#             Discipline  NOC Gender                       Event Event_gender  \
# ...

# %%
###  summary of total medal won in 2008

k= oo[oo.Edition == 2008]

# %%
k
# Out:
#                     Athlete  level_0  index     City  Edition      Sport  \
# 27174        GALPERIN, Gleb    27174  27174  Beijing     2008   Aquatics
# 27175      MITCHAM, Matthew    27175  27175  Beijing     2008   Aquatics
# 27176           ZHOU, Luxin    27176  27176  Beijing     2008   Aquatics
# 27177             WANG, Xin    27177  27177  Beijing     2008   Aquatics
# 27178          CHEN, Ruolin    27178  27178  Beijing     2008   Aquatics
# ...                     ...      ...    ...      ...      ...        ...
# 29211        ENGLICH, Mirko    29211  29211  Beijing     2008  Wrestling
# 29212  MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# 29213       PATRIKEEV, Yuri    29213  29213  Beijing     2008  Wrestling
# 29214         LOPEZ, Mijain    29214  29214  Beijing     2008  Wrestling
# 29215        BAROEV, Khasan    29215  29215  Beijing     2008  Wrestling
#
#             Discipline  NOC Gender         Event Event_gender   Medal
# ...

# %%
m= k.groupby(['NOC','Medal']).size().unstack('Medal', fill_value=0)

# %%
m
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AFG         1     0       0
# ALG         1     0       1
# ARG        31    20       0
# ARM         6     0       0
# AUS        76    31      42
# ..        ...   ...     ...
# USA        81   125     109
# UZB         3     1       2
# VEN         1     0       0
# VIE         0     0       1
# ZIM         0     1       3
#
# [86 rows x 3 columns]

# %%
m= m.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]

# %%
m
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
import seaborn as sms
sms.heatmap(m)
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='NOC'>

# %%
### WHICH US ATHLETE HAS WON THE MOST TOTAL MEDALS INCLUDE ATHLETE DISCIPLINE

oo
# Out:
#                     Athlete  level_0  index     City  Edition      Sport  \
# 0             HAJOS, Alfred        0      0   Athens     1896   Aquatics
# 1          HERSCHMANN, Otto        1      1   Athens     1896   Aquatics
# 2         DRIVAS, Dimitrios        2      2   Athens     1896   Aquatics
# 3        MALOKINIS, Ioannis        3      3   Athens     1896   Aquatics
# 4        CHASAPIS, Spiridon        4      4   Athens     1896   Aquatics
# ...                     ...      ...    ...      ...      ...        ...
# 29211        ENGLICH, Mirko    29211  29211  Beijing     2008  Wrestling
# 29212  MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# 29213       PATRIKEEV, Yuri    29213  29213  Beijing     2008  Wrestling
# 29214         LOPEZ, Mijain    29214  29214  Beijing     2008  Wrestling
# 29215        BAROEV, Khasan    29215  29215  Beijing     2008  Wrestling
#
#             Discipline  NOC Gender                       Event Event_gender  \
# ...

# %%
P= oo[oo.NOC == 'USA']
P
# Out:
#                Athlete  level_0  index     City  Edition       Sport  \
# 11       LANE, Francis       11     11   Athens     1896   Athletics
# 13       BURKE, Thomas       13     13   Athens     1896   Athletics
# 15      CURTIS, Thomas       15     15   Athens     1896   Athletics
# 19       BLAKE, Arthur       19     19   Athens     1896   Athletics
# 21       BURKE, Thomas       21     21   Athens     1896   Athletics
# ...                ...      ...    ...      ...      ...         ...
# 29098       TOM, Logan    29098  29098  Beijing     2008  Volleyball
# 29099  WILLOUGHBY, Kim    29099  29099  Beijing     2008  Volleyball
# 29151    CEJUDO, Henry    29151  29151  Beijing     2008   Wrestling
# 29161    MILLER, Randi    29161  29161  Beijing     2008   Wrestling
# 29209    WHEELER, Adam    29209  29209  Beijing     2008   Wrestling
#
#             Discipline  NOC Gender         Event Event_gender   Medal
# ...

# %%
q= P[['Athlete', 'Medal']]
q
# Out:
#                Athlete   Medal
# 11       LANE, Francis  Bronze
# 13       BURKE, Thomas    Gold
# 15      CURTIS, Thomas    Gold
# 19       BLAKE, Arthur  Silver
# 21       BURKE, Thomas    Gold
# ...                ...     ...
# 29098       TOM, Logan  Silver
# 29099  WILLOUGHBY, Kim  Silver
# 29151    CEJUDO, Henry    Gold
# 29161    MILLER, Randi  Bronze
# 29209    WHEELER, Adam  Bronze
#
# [4335 rows x 2 columns]

# %%
qq= q.groupby('Athlete').count()
qq
# Out:
#                        Medal
# Athlete
# ABAS, Stephen              1
# ABBOTT, Margaret Ives      1
# ABBOTT, Monica             1
# ABDALLAH, Nia              1
# ABDUR-RAHIM, Shareef       1
# ...                      ...
# ZIMONYI, Robert            1
# ZIRKEL, Albert             1
# ZMESKAL, Kim               1
# ZOCH, Jacqueline Jean      1
# ZORN, Zachary              1
#
# [3012 rows x 1 columns]

# %%
kq= qq.sort_values('Medal', ascending=False)

# %%
kq.head(25)
# Out:
#                             Medal
# Athlete
# PHELPS, Michael                16
# THOMPSON, Jenny                12
# TORRES, Dara                   12
# BIONDI, Matthew                11
# COUGHLIN, Natalie              11
# OSBURN, Carl Townsend          11
# SPITZ, Mark                    11
# HALL, Gary Jr.                 10
# LEWIS, Carl                    10
# BABASHOFF, Shirley Farber       8
# EWRY, Ray                       8
# BEARD, Amanda                   7
# PEIRSOL, Aaron                  7
# LEE, Willis                     7
# LEZAK, Jason                    7
# MILLER, Shannon                 7
# SPOONER, Lloyd Spencer          7
# DANIELS, Charles                7
# SCHOLLANDER, Donald Arthur      6
# PLUMB, John Michael             6
# EYSER, George                   6
# DOWNING, Burton                 6
# LANE, Alfred P.                 6
# JOYNER-KERSEE, Jackie           6
# GARRETT, Robert                 6
